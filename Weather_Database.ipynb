# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
from config import g_key

# %%
import time
from datetime import datetime

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 769

# %%
city_weather = requests.get(url)
city_weather
# Out:
# <Response [400]>

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):

    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    city_url = url + "&q=" + city.replace(" ","+")

    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    record_count += 1
    
    try:
        
        city_weather = requests.get(city_url).json()

        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_descr = city_weather["weather"][0]["description"]
        
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')

        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description":city_descr,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | severo-kurilsk
# Processing Record 3 of Set 1 | bathsheba
# Processing Record 4 of Set 1 | souillac
# Processing Record 5 of Set 1 | tombouctou
# Processing Record 6 of Set 1 | faanui
# Processing Record 7 of Set 1 | hithadhoo
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | hermanus
# Processing Record 10 of Set 1 | dikson
# Processing Record 11 of Set 1 | tuktoyaktuk
# Processing Record 12 of Set 1 | west bay
# Processing Record 13 of Set 1 | yellowknife
# Processing Record 14 of Set 1 | mana
# Processing Record 15 of Set 1 | ambodifototra
# City not found. Skipping...
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | kaitangata
# Processing Record 19 of Set 1 | mar del plata
# Processing Record 20 of Set 1 | svetlyy
# Processing Record 21 of Set 1 | fairbanks
# Processing Record 22 of Set 1 | kapaa
# Processing Record 23 of Set 1 | okhotsk
# Processing Record 24 of Set 1 | new norfolk
# Processing Record 25 of Set 1 | guerrero negro
# Processing Record 26 of Set 1 | alugan
# Processing Record 27 of Set 1 | tarakan
# Processing Record 28 of Set 1 | kirakira
# Processing Record 29 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 1 | flin flon
# Processing Record 31 of Set 1 | east london
# Processing Record 32 of Set 1 | nikolskoye
# Processing Record 33 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 1 | port hardy
# Processing Record 35 of Set 1 | tiksi
# Processing Record 36 of Set 1 | ponta do sol
# Processing Record 37 of Set 1 | luderitz
# Processing Record 38 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 1 | port elizabeth
# Processing Record 40 of Set 1 | belmonte
# Processing Record 41 of Set 1 | puri
# Processing Record 42 of Set 1 | acatlan
# Processing Record 43 of Set 1 | port blair
# Processing Record 44 of Set 1 | airai
# Processing Record 45 of Set 1 | chuy
# Processing Record 46 of Set 1 | iqaluit
# Processing Record 47 of Set 1 | avarua
# Processing Record 48 of Set 1 | rikitea
# Processing Record 49 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 1 | cape town
# Processing Record 1 of Set 2 | san cristobal
# Processing Record 2 of Set 2 | ambon
# Processing Record 3 of Set 2 | lata
# Processing Record 4 of Set 2 | waipawa
# Processing Record 5 of Set 2 | el alto
# Processing Record 6 of Set 2 | ribeira grande
# Processing Record 7 of Set 2 | linares
# Processing Record 8 of Set 2 | tasiilaq
# Processing Record 9 of Set 2 | saskylakh
# Processing Record 10 of Set 2 | bonga
# Processing Record 11 of Set 2 | vaini
# Processing Record 12 of Set 2 | kisangani
# Processing Record 13 of Set 2 | nanortalik
# Processing Record 14 of Set 2 | izumo
# Processing Record 15 of Set 2 | cherskiy
# Processing Record 16 of Set 2 | houma
# Processing Record 17 of Set 2 | cidreira
# Processing Record 18 of Set 2 | murashi
# Processing Record 19 of Set 2 | bengkulu
# Processing Record 20 of Set 2 | nagato
# Processing Record 21 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 22 of Set 2 | boshnyakovo
# Processing Record 23 of Set 2 | svetlogorsk
# Processing Record 24 of Set 2 | marion
# Processing Record 25 of Set 2 | necochea
# Processing Record 26 of Set 2 | butaritari
# Processing Record 27 of Set 2 | simao
# Processing Record 28 of Set 2 | port alfred
# Processing Record 29 of Set 2 | baruun-urt
# Processing Record 30 of Set 2 | yulara
# Processing Record 31 of Set 2 | barrow
# Processing Record 32 of Set 2 | clyde river
# Processing Record 33 of Set 2 | khatanga
# Processing Record 34 of Set 2 | jamestown
# Processing Record 35 of Set 2 | tubuala
# Processing Record 36 of Set 2 | salinopolis
# Processing Record 37 of Set 2 | hilo
# Processing Record 38 of Set 2 | acapulco
# Processing Record 39 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 41 of Set 2 | one hundred mile house
# City not found. Skipping...
# Processing Record 42 of Set 2 | bada
# Processing Record 43 of Set 2 | kampot
# Processing Record 44 of Set 2 | yenagoa
# Processing Record 45 of Set 2 | mahebourg
# Processing Record 46 of Set 2 | te anau
# Processing Record 47 of Set 2 | hobart
# Processing Record 48 of Set 2 | talnakh
# Processing Record 49 of Set 2 | saint-augustin
# Processing Record 50 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 3 | sao filipe
# Processing Record 2 of Set 3 | lagoa
# Processing Record 3 of Set 3 | gilazi
# City not found. Skipping...
# Processing Record 4 of Set 3 | busselton
# Processing Record 5 of Set 3 | cayenne
# Processing Record 6 of Set 3 | russell
# Processing Record 7 of Set 3 | karratha
# Processing Record 8 of Set 3 | san quintin
# Processing Record 9 of Set 3 | verkhnyaya toyma
# Processing Record 10 of Set 3 | christchurch
# Processing Record 11 of Set 3 | chokurdakh
# Processing Record 12 of Set 3 | cockburn town
# Processing Record 13 of Set 3 | castro
# Processing Record 14 of Set 3 | gus-zheleznyy
# Processing Record 15 of Set 3 | ornskoldsvik
# Processing Record 16 of Set 3 | inverell
# Processing Record 17 of Set 3 | caravelas
# Processing Record 18 of Set 3 | ancud
# Processing Record 19 of Set 3 | sitka
# Processing Record 20 of Set 3 | umm lajj
# Processing Record 21 of Set 3 | mount isa
# Processing Record 22 of Set 3 | lebu
# Processing Record 23 of Set 3 | bolsheustikinskoye
# City not found. Skipping...
# Processing Record 24 of Set 3 | qaanaaq
# Processing Record 25 of Set 3 | alice springs
# Processing Record 26 of Set 3 | duzici
# City not found. Skipping...
# Processing Record 27 of Set 3 | rohtak
# Processing Record 28 of Set 3 | macenta
# Processing Record 29 of Set 3 | dunedin
# Processing Record 30 of Set 3 | turbat
# Processing Record 31 of Set 3 | kristiansund
# Processing Record 32 of Set 3 | meadow lake
# Processing Record 33 of Set 3 | agadez
# Processing Record 34 of Set 3 | georgetown
# Processing Record 35 of Set 3 | vardo
# Processing Record 36 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 37 of Set 3 | atuona
# Processing Record 38 of Set 3 | sao joao da barra
# Processing Record 39 of Set 3 | chipinge
# Processing Record 40 of Set 3 | bredasdorp
# Processing Record 41 of Set 3 | linhares
# Processing Record 42 of Set 3 | sarh
# Processing Record 43 of Set 3 | beringovskiy
# Processing Record 44 of Set 3 | yashkul
# Processing Record 45 of Set 3 | sao felix do xingu
# Processing Record 46 of Set 3 | grindavik
# Processing Record 47 of Set 3 | qui nhon
# Processing Record 48 of Set 3 | hornepayne
# Processing Record 49 of Set 3 | bluff
# Processing Record 50 of Set 3 | fortuna
# Processing Record 1 of Set 4 | strezhevoy
# Processing Record 2 of Set 4 | kavaratti
# Processing Record 3 of Set 4 | manggar
# Processing Record 4 of Set 4 | shimoda
# Processing Record 5 of Set 4 | sorland
# Processing Record 6 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 7 of Set 4 | ilulissat
# Processing Record 8 of Set 4 | lavrentiya
# Processing Record 9 of Set 4 | pisco
# Processing Record 10 of Set 4 | victoria
# Processing Record 11 of Set 4 | katsuura
# Processing Record 12 of Set 4 | araouane
# Processing Record 13 of Set 4 | otofuke
# Processing Record 14 of Set 4 | yinchuan
# Processing Record 15 of Set 4 | rawson
# Processing Record 16 of Set 4 | komsomolskiy
# Processing Record 17 of Set 4 | saint-philippe
# Processing Record 18 of Set 4 | kurchum
# Processing Record 19 of Set 4 | saint george
# Processing Record 20 of Set 4 | san policarpo
# Processing Record 21 of Set 4 | ligayan
# Processing Record 22 of Set 4 | yelan-koleno
# Processing Record 23 of Set 4 | black river
# Processing Record 24 of Set 4 | norman wells
# Processing Record 25 of Set 4 | charlestown
# Processing Record 26 of Set 4 | barahona
# Processing Record 27 of Set 4 | esperance
# Processing Record 28 of Set 4 | tazovskiy
# Processing Record 29 of Set 4 | saysain
# Processing Record 30 of Set 4 | richards bay
# Processing Record 31 of Set 4 | dondo
# Processing Record 32 of Set 4 | longyearbyen
# Processing Record 33 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 4 | cabedelo
# Processing Record 36 of Set 4 | qiongshan
# Processing Record 37 of Set 4 | tutoia
# Processing Record 38 of Set 4 | benguela
# Processing Record 39 of Set 4 | ola
# Processing Record 40 of Set 4 | tabas
# Processing Record 41 of Set 4 | bilibino
# Processing Record 42 of Set 4 | rocha
# Processing Record 43 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 44 of Set 4 | roald
# Processing Record 45 of Set 4 | maceio
# Processing Record 46 of Set 4 | nannilam
# Processing Record 47 of Set 4 | upernavik
# Processing Record 48 of Set 4 | dongsheng
# Processing Record 49 of Set 4 | oriximina
# Processing Record 50 of Set 4 | kudahuvadhoo
# Processing Record 1 of Set 5 | prince rupert
# Processing Record 2 of Set 5 | labuan
# Processing Record 3 of Set 5 | potamia
# Processing Record 4 of Set 5 | taoudenni
# Processing Record 5 of Set 5 | bardiyah
# Processing Record 6 of Set 5 | klaksvik
# Processing Record 7 of Set 5 | huangchuan
# Processing Record 8 of Set 5 | havre-saint-pierre
# Processing Record 9 of Set 5 | lengshuitan
# Processing Record 10 of Set 5 | sandpoint
# Processing Record 11 of Set 5 | pangody
# Processing Record 12 of Set 5 | quatre cocos
# Processing Record 13 of Set 5 | provideniya
# Processing Record 14 of Set 5 | zemio
# Processing Record 15 of Set 5 | yuli
# Processing Record 16 of Set 5 | snyder
# Processing Record 17 of Set 5 | senmonorom
# City not found. Skipping...
# Processing Record 18 of Set 5 | thompson
# Processing Record 19 of Set 5 | luba
# Processing Record 20 of Set 5 | san patricio
# Processing Record 21 of Set 5 | kahului
# Processing Record 22 of Set 5 | mehriz
# Processing Record 23 of Set 5 | aklavik
# Processing Record 24 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 25 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 5 | broome
# Processing Record 27 of Set 5 | isangel
# Processing Record 28 of Set 5 | anzio
# Processing Record 29 of Set 5 | arnedo
# Processing Record 30 of Set 5 | ballina
# Processing Record 31 of Set 5 | balabac
# Processing Record 32 of Set 5 | geraldton
# Processing Record 33 of Set 5 | plettenberg bay
# Processing Record 34 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 35 of Set 5 | istisu
# Processing Record 36 of Set 5 | padang
# Processing Record 37 of Set 5 | srednekolymsk
# Processing Record 38 of Set 5 | lakatoro
# Processing Record 39 of Set 5 | kariba
# Processing Record 40 of Set 5 | tecoanapa
# Processing Record 41 of Set 5 | karlskoga
# Processing Record 42 of Set 5 | maghama
# City not found. Skipping...
# Processing Record 43 of Set 5 | bambous virieux
# Processing Record 44 of Set 5 | vostok
# Processing Record 45 of Set 5 | boyolangu
# Processing Record 46 of Set 5 | ebano
# City not found. Skipping...
# Processing Record 47 of Set 5 | iwanai
# Processing Record 48 of Set 5 | caldas novas
# Processing Record 49 of Set 5 | goundam
# Processing Record 50 of Set 5 | nioro
# Processing Record 1 of Set 6 | udachnyy
# Processing Record 2 of Set 6 | dariba
# Processing Record 3 of Set 6 | dingle
# Processing Record 4 of Set 6 | manicore
# Processing Record 5 of Set 6 | tidore
# City not found. Skipping...
# Processing Record 6 of Set 6 | carnarvon
# Processing Record 7 of Set 6 | saint-francois
# Processing Record 8 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 6 | muriwai beach
# Processing Record 10 of Set 6 | seymchan
# Processing Record 11 of Set 6 | garowe
# Processing Record 12 of Set 6 | corum
# Processing Record 13 of Set 6 | puerto escondido
# Processing Record 14 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 15 of Set 6 | pacific grove
# Processing Record 16 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 17 of Set 6 | timra
# Processing Record 18 of Set 6 | goderich
# Processing Record 19 of Set 6 | grand gaube
# Processing Record 20 of Set 6 | noumea
# Processing Record 21 of Set 6 | tawkar
# City not found. Skipping...
# Processing Record 22 of Set 6 | siderno
# Processing Record 23 of Set 6 | yar-sale
# Processing Record 24 of Set 6 | belle glade
# Processing Record 25 of Set 6 | novosokolniki
# Processing Record 26 of Set 6 | bethel
# Processing Record 27 of Set 6 | damietta
# Processing Record 28 of Set 6 | bac lieu
# Processing Record 29 of Set 6 | liverpool
# Processing Record 30 of Set 6 | nova olimpia
# Processing Record 31 of Set 6 | telsiai
# Processing Record 32 of Set 6 | nishihara
# Processing Record 33 of Set 6 | odweyne
# Processing Record 34 of Set 6 | kysyl-syr
# Processing Record 35 of Set 6 | kodiak
# Processing Record 36 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 37 of Set 6 | damaturu
# Processing Record 38 of Set 6 | dekoa
# City not found. Skipping...
# Processing Record 39 of Set 6 | shelburne
# Processing Record 40 of Set 6 | lompoc
# Processing Record 41 of Set 6 | hokitika
# Processing Record 42 of Set 6 | swellendam
# Processing Record 43 of Set 6 | kawalu
# Processing Record 44 of Set 6 | chapais
# Processing Record 45 of Set 6 | salalah
# Processing Record 46 of Set 6 | teya
# Processing Record 47 of Set 6 | jesup
# Processing Record 48 of Set 6 | fevralsk
# City not found. Skipping...
# Processing Record 49 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 50 of Set 6 | dalmau
# Processing Record 1 of Set 7 | farnham
# Processing Record 2 of Set 7 | katherine
# Processing Record 3 of Set 7 | comodoro rivadavia
# Processing Record 4 of Set 7 | aykhal
# Processing Record 5 of Set 7 | nizhniy tsasuchey
# Processing Record 6 of Set 7 | huarmey
# Processing Record 7 of Set 7 | elat
# Processing Record 8 of Set 7 | kelvington
# Processing Record 9 of Set 7 | vestmannaeyjar
# Processing Record 10 of Set 7 | dom pedrito
# Processing Record 11 of Set 7 | saldanha
# Processing Record 12 of Set 7 | ishigaki
# Processing Record 13 of Set 7 | lesozavodsk
# Processing Record 14 of Set 7 | vila velha
# Processing Record 15 of Set 7 | riyadh
# Processing Record 16 of Set 7 | mangrol
# Processing Record 17 of Set 7 | erzin
# Processing Record 18 of Set 7 | nuevo progreso
# Processing Record 19 of Set 7 | togur
# Processing Record 20 of Set 7 | trinidad
# Processing Record 21 of Set 7 | champawat
# Processing Record 22 of Set 7 | anadyr
# Processing Record 23 of Set 7 | camabatela
# Processing Record 24 of Set 7 | abasolo
# Processing Record 25 of Set 7 | constitucion
# Processing Record 26 of Set 7 | brownsville
# Processing Record 27 of Set 7 | onega
# Processing Record 28 of Set 7 | tecpan
# Processing Record 29 of Set 7 | luziania
# Processing Record 30 of Set 7 | longlac
# City not found. Skipping...
# Processing Record 31 of Set 7 | eyl
# Processing Record 32 of Set 7 | walvis bay
# Processing Record 33 of Set 7 | teguldet
# Processing Record 34 of Set 7 | tiarei
# Processing Record 35 of Set 7 | puerto leguizamo
# Processing Record 36 of Set 7 | bhunya
# Processing Record 37 of Set 7 | arraial do cabo
# Processing Record 38 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 7 | ipixuna
# Processing Record 40 of Set 7 | puerto ayora
# Processing Record 41 of Set 7 | saint-joseph
# Processing Record 42 of Set 7 | yerbogachen
# Processing Record 43 of Set 7 | karatau
# Processing Record 44 of Set 7 | mutsamudu
# City not found. Skipping...
# Processing Record 45 of Set 7 | jimenez
# Processing Record 46 of Set 7 | muret
# Processing Record 47 of Set 7 | narsaq
# Processing Record 48 of Set 7 | pilar
# Processing Record 49 of Set 7 | emerald
# Processing Record 50 of Set 7 | taltal
# Processing Record 1 of Set 8 | bauta
# Processing Record 2 of Set 8 | hasaki
# Processing Record 3 of Set 8 | dinsor
# City not found. Skipping...
# Processing Record 4 of Set 8 | natal
# Processing Record 5 of Set 8 | safaga
# Processing Record 6 of Set 8 | ahumada
# City not found. Skipping...
# Processing Record 7 of Set 8 | blackwater
# Processing Record 8 of Set 8 | meulaboh
# Processing Record 9 of Set 8 | ca mau
# Processing Record 10 of Set 8 | gravdal
# Processing Record 11 of Set 8 | lubango
# Processing Record 12 of Set 8 | ulladulla
# Processing Record 13 of Set 8 | puerto el triunfo
# Processing Record 14 of Set 8 | kragero
# Processing Record 15 of Set 8 | paamiut
# Processing Record 16 of Set 8 | biak
# Processing Record 17 of Set 8 | qandahar
# City not found. Skipping...
# Processing Record 18 of Set 8 | kavieng
# Processing Record 19 of Set 8 | busembatia
# Processing Record 20 of Set 8 | luanda
# Processing Record 21 of Set 8 | alofi
# Processing Record 22 of Set 8 | sabha
# Processing Record 23 of Set 8 | nata
# Processing Record 24 of Set 8 | dwarka
# Processing Record 25 of Set 8 | lewisporte
# Processing Record 26 of Set 8 | shenjiamen
# Processing Record 27 of Set 8 | jalu
# Processing Record 28 of Set 8 | terenos
# Processing Record 29 of Set 8 | vallenar
# Processing Record 30 of Set 8 | murighiol
# Processing Record 31 of Set 8 | hamilton
# Processing Record 32 of Set 8 | severodvinsk
# Processing Record 33 of Set 8 | buriti bravo
# Processing Record 34 of Set 8 | temaraia
# City not found. Skipping...
# Processing Record 35 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 8 | afzalpur
# Processing Record 37 of Set 8 | cabo san lucas
# Processing Record 38 of Set 8 | caninde
# Processing Record 39 of Set 8 | qandala
# Processing Record 40 of Set 8 | davila
# Processing Record 41 of Set 8 | la sarre
# Processing Record 42 of Set 8 | bairiki
# Processing Record 43 of Set 8 | puerto quijarro
# Processing Record 44 of Set 8 | gwadar
# Processing Record 45 of Set 8 | jutai
# Processing Record 46 of Set 8 | naze
# Processing Record 47 of Set 8 | burnie
# Processing Record 48 of Set 8 | bonthe
# Processing Record 49 of Set 8 | ostrovnoy
# Processing Record 50 of Set 8 | celestun
# Processing Record 1 of Set 9 | honiara
# Processing Record 2 of Set 9 | berdigestyakh
# Processing Record 3 of Set 9 | pachino
# Processing Record 4 of Set 9 | qaqortoq
# Processing Record 5 of Set 9 | ratnagiri
# Processing Record 6 of Set 9 | braslav
# City not found. Skipping...
# Processing Record 7 of Set 9 | seoul
# Processing Record 8 of Set 9 | sangar
# Processing Record 9 of Set 9 | san juan
# Processing Record 10 of Set 9 | ahipara
# Processing Record 11 of Set 9 | tuatapere
# Processing Record 12 of Set 9 | puerto baquerizo moreno
# Processing Record 13 of Set 9 | kungurtug
# Processing Record 14 of Set 9 | bontang
# Processing Record 15 of Set 9 | pandan
# Processing Record 16 of Set 9 | huilong
# Processing Record 17 of Set 9 | avera
# Processing Record 18 of Set 9 | avesta
# Processing Record 19 of Set 9 | la palma
# Processing Record 20 of Set 9 | arrifes
# Processing Record 21 of Set 9 | porto santo
# Processing Record 22 of Set 9 | tessalit
# Processing Record 23 of Set 9 | skagastrond
# City not found. Skipping...
# Processing Record 24 of Set 9 | mama
# Processing Record 25 of Set 9 | havelock
# Processing Record 26 of Set 9 | antofagasta
# Processing Record 27 of Set 9 | bundaberg
# Processing Record 28 of Set 9 | wangdiphodrang
# City not found. Skipping...
# Processing Record 29 of Set 9 | ketchikan
# Processing Record 30 of Set 9 | toamasina
# Processing Record 31 of Set 9 | karamea
# City not found. Skipping...
# Processing Record 32 of Set 9 | inhambane
# Processing Record 33 of Set 9 | haines junction
# Processing Record 34 of Set 9 | victoria point
# Processing Record 35 of Set 9 | narasannapeta
# Processing Record 36 of Set 9 | pleasanton
# Processing Record 37 of Set 9 | hambantota
# Processing Record 38 of Set 9 | dibaya
# City not found. Skipping...
# Processing Record 39 of Set 9 | sao gabriel da cachoeira
# Processing Record 40 of Set 9 | sale
# Processing Record 41 of Set 9 | riberalta
# Processing Record 42 of Set 9 | atar
# Processing Record 43 of Set 9 | urgut
# Processing Record 44 of Set 9 | ekibastuz
# Processing Record 45 of Set 9 | gazli
# Processing Record 46 of Set 9 | nome
# Processing Record 47 of Set 9 | mabai
# Processing Record 48 of Set 9 | spearfish
# Processing Record 49 of Set 9 | jishou
# Processing Record 50 of Set 9 | illapel
# Processing Record 1 of Set 10 | terrace bay
# Processing Record 2 of Set 10 | carauari
# Processing Record 3 of Set 10 | mitsamiouli
# Processing Record 4 of Set 10 | victor harbor
# Processing Record 5 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 6 of Set 10 | sao jose da coroa grande
# Processing Record 7 of Set 10 | fuchu
# Processing Record 8 of Set 10 | san jeronimo
# Processing Record 9 of Set 10 | kaeo
# Processing Record 10 of Set 10 | golden
# Processing Record 11 of Set 10 | gizo
# Processing Record 12 of Set 10 | ryotsu
# Processing Record 13 of Set 10 | northam
# Processing Record 14 of Set 10 | suzun
# Processing Record 15 of Set 10 | krasnyy chikoy
# Processing Record 16 of Set 10 | leningradskiy
# Processing Record 17 of Set 10 | mergui
# City not found. Skipping...
# Processing Record 18 of Set 10 | bulungu
# Processing Record 19 of Set 10 | northfield
# Processing Record 20 of Set 10 | bandarbeyla
# Processing Record 21 of Set 10 | zlatoustovsk
# City not found. Skipping...
# Processing Record 22 of Set 10 | sakaiminato
# Processing Record 23 of Set 10 | zhuhai
# Processing Record 24 of Set 10 | madison
# Processing Record 25 of Set 10 | marystown
# Processing Record 26 of Set 10 | yanam
# Processing Record 27 of Set 10 | kearney
# Processing Record 28 of Set 10 | abha
# Processing Record 29 of Set 10 | kollumerland
# City not found. Skipping...
# Processing Record 30 of Set 10 | biloxi
# Processing Record 31 of Set 10 | ramgarh
# Processing Record 32 of Set 10 | guantanamo
# Processing Record 33 of Set 10 | henties bay
# Processing Record 34 of Set 10 | kuytun
# Processing Record 35 of Set 10 | koungou
# Processing Record 36 of Set 10 | kumba
# Processing Record 37 of Set 10 | marsh harbour
# Processing Record 38 of Set 10 | marsabit
# Processing Record 39 of Set 10 | mahajanga
# Processing Record 40 of Set 10 | bubaque
# Processing Record 41 of Set 10 | imbituba
# Processing Record 42 of Set 10 | capaci
# Processing Record 43 of Set 10 | kwekwe
# Processing Record 44 of Set 10 | muktsar
# Processing Record 45 of Set 10 | chancay
# Processing Record 46 of Set 10 | husavik
# Processing Record 47 of Set 10 | haimen
# Processing Record 48 of Set 10 | mantua
# Processing Record 49 of Set 10 | touros
# Processing Record 50 of Set 10 | hualmay
# Processing Record 1 of Set 11 | santa rosa
# Processing Record 2 of Set 11 | saint anthony
# Processing Record 3 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 11 | vyatskiye polyany
# Processing Record 5 of Set 11 | korla
# Processing Record 6 of Set 11 | mersin
# Processing Record 7 of Set 11 | keti bandar
# Processing Record 8 of Set 11 | asosa
# Processing Record 9 of Set 11 | itarema
# Processing Record 10 of Set 11 | inirida
# Processing Record 11 of Set 11 | tshikapa
# Processing Record 12 of Set 11 | taksimo
# Processing Record 13 of Set 11 | bari
# Processing Record 14 of Set 11 | leninskoye
# Processing Record 15 of Set 11 | xinyu
# Processing Record 16 of Set 11 | mayo
# Processing Record 17 of Set 11 | gat
# Processing Record 18 of Set 11 | axim
# Processing Record 19 of Set 11 | miyako
# Processing Record 20 of Set 11 | palmer
# Processing Record 21 of Set 11 | vestmanna
# Processing Record 22 of Set 11 | manacapuru
# Processing Record 23 of Set 11 | buala
# Processing Record 24 of Set 11 | nouadhibou
# Processing Record 25 of Set 11 | maryanovka
# City not found. Skipping...
# Processing Record 26 of Set 11 | port-cartier
# Processing Record 27 of Set 11 | la tuque
# Processing Record 28 of Set 11 | sindor
# Processing Record 29 of Set 11 | juneau
# Processing Record 30 of Set 11 | brae
# Processing Record 31 of Set 11 | somanda
# Processing Record 32 of Set 11 | chimoio
# Processing Record 33 of Set 11 | ndiekro
# City not found. Skipping...
# Processing Record 34 of Set 11 | coruripe
# Processing Record 35 of Set 11 | kruisfontein
# Processing Record 36 of Set 11 | olafsvik
# Processing Record 37 of Set 11 | moron
# Processing Record 38 of Set 11 | milingimbi
# City not found. Skipping...
# Processing Record 39 of Set 11 | champasak
# Processing Record 40 of Set 11 | yarkovo
# Processing Record 41 of Set 11 | whitianga
# Processing Record 42 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 43 of Set 11 | oistins
# Processing Record 44 of Set 11 | takoradi
# Processing Record 45 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 46 of Set 11 | catuday
# Processing Record 47 of Set 11 | pevek
# Processing Record 48 of Set 11 | tuy hoa
# Processing Record 49 of Set 11 | angoram
# Processing Record 50 of Set 11 | mount gambier
# Processing Record 1 of Set 12 | shingu
# Processing Record 2 of Set 12 | shchuchye
# City not found. Skipping...
# Processing Record 3 of Set 12 | phan thiet
# Processing Record 4 of Set 12 | isiro
# Processing Record 5 of Set 12 | tsagan aman
# Processing Record 6 of Set 12 | namatanai
# Processing Record 7 of Set 12 | ucluelet
# Processing Record 8 of Set 12 | gondanglegi
# Processing Record 9 of Set 12 | luwingu
# Processing Record 10 of Set 12 | high level
# Processing Record 11 of Set 12 | traverse city
# Processing Record 12 of Set 12 | najran
# Processing Record 13 of Set 12 | orcopampa
# Processing Record 14 of Set 12 | ileza
# Processing Record 15 of Set 12 | kutum
# Processing Record 16 of Set 12 | ilhabela
# Processing Record 17 of Set 12 | dullewala
# Processing Record 18 of Set 12 | whitehorse
# Processing Record 19 of Set 12 | excelsior springs
# Processing Record 20 of Set 12 | tomatlan
# Processing Record 21 of Set 12 | mingshui
# Processing Record 22 of Set 12 | lac du bonnet
# Processing Record 23 of Set 12 | poso
# Processing Record 24 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 25 of Set 12 | mirabad
# Processing Record 26 of Set 12 | golynki
# Processing Record 27 of Set 12 | ranong
# Processing Record 28 of Set 12 | bud
# Processing Record 29 of Set 12 | palaia fokaia
# Processing Record 30 of Set 12 | channel-port aux basques
# Processing Record 31 of Set 12 | mlonggo
# Processing Record 32 of Set 12 | westpunt
# City not found. Skipping...
# Processing Record 33 of Set 12 | alekseyevsk
# Processing Record 34 of Set 12 | suleja
# Processing Record 35 of Set 12 | dalvik
# Processing Record 36 of Set 12 | aktau
# Processing Record 37 of Set 12 | tilichiki
# Processing Record 38 of Set 12 | kangaatsiaq
# Processing Record 39 of Set 12 | tete
# Processing Record 40 of Set 12 | kuala terengganu
# Processing Record 41 of Set 12 | ambunti
# Processing Record 42 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 43 of Set 12 | acarau
# Processing Record 44 of Set 12 | deniliquin
# Processing Record 45 of Set 12 | menongue
# Processing Record 46 of Set 12 | karatuzskoye
# Processing Record 47 of Set 12 | floro
# Processing Record 48 of Set 12 | sibolga
# Processing Record 49 of Set 12 | arman
# Processing Record 50 of Set 12 | gornopravdinsk
# Processing Record 1 of Set 13 | korem
# Processing Record 2 of Set 13 | san ramon
# Processing Record 3 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 4 of Set 13 | hongjiang
# Processing Record 5 of Set 13 | ejido
# Processing Record 6 of Set 13 | fort saint james
# Processing Record 7 of Set 13 | vao
# Processing Record 8 of Set 13 | brigantine
# Processing Record 9 of Set 13 | port lincoln
# Processing Record 10 of Set 13 | egvekinot
# Processing Record 11 of Set 13 | makaha
# Processing Record 12 of Set 13 | kendari
# Processing Record 13 of Set 13 | subaytilah
# City not found. Skipping...
# Processing Record 14 of Set 13 | dudinka
# Processing Record 15 of Set 13 | zhigansk
# Processing Record 16 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 17 of Set 13 | kampene
# Processing Record 18 of Set 13 | juxian
# City not found. Skipping...
# Processing Record 19 of Set 13 | verkh-usugli
# Processing Record 20 of Set 13 | manali
# Processing Record 21 of Set 13 | makakilo city
# Processing Record 22 of Set 13 | kidal
# Processing Record 23 of Set 13 | chimore
# Processing Record 24 of Set 13 | auki
# Processing Record 25 of Set 13 | nantucket
# Processing Record 26 of Set 13 | ayan
# Processing Record 27 of Set 13 | summerland
# Processing Record 28 of Set 13 | samarai
# Processing Record 29 of Set 13 | sisimiut
# Processing Record 30 of Set 13 | rio gallegos
# Processing Record 31 of Set 13 | southampton
# Processing Record 32 of Set 13 | presidencia roque saenz pena
# Processing Record 33 of Set 13 | solnechnyy
# Processing Record 34 of Set 13 | verkhnyaya inta
# Processing Record 35 of Set 13 | grand forks
# Processing Record 36 of Set 13 | prince albert
# Processing Record 37 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 38 of Set 13 | road town
# Processing Record 39 of Set 13 | marawi
# Processing Record 40 of Set 13 | abeche
# Processing Record 41 of Set 13 | samana
# Processing Record 42 of Set 13 | anklam
# Processing Record 43 of Set 13 | porbandar
# Processing Record 44 of Set 13 | kedrovyy
# Processing Record 45 of Set 13 | warrnambool
# Processing Record 46 of Set 13 | topolobampo
# Processing Record 47 of Set 13 | avdon
# Processing Record 48 of Set 13 | khani
# Processing Record 49 of Set 13 | huancabamba
# Processing Record 50 of Set 13 | tlaxco
# Processing Record 1 of Set 14 | dulovo
# Processing Record 2 of Set 14 | inderborskiy
# City not found. Skipping...
# Processing Record 3 of Set 14 | mendi
# Processing Record 4 of Set 14 | kamiiso
# Processing Record 5 of Set 14 | terrace
# Processing Record 6 of Set 14 | okato
# Processing Record 7 of Set 14 | paradwip
# City not found. Skipping...
# Processing Record 8 of Set 14 | kishorganj
# Processing Record 9 of Set 14 | stonehaven
# Processing Record 10 of Set 14 | astoria
# Processing Record 11 of Set 14 | komsomolsk-na-amure
# Processing Record 12 of Set 14 | tucurui
# Processing Record 13 of Set 14 | siniscola
# Processing Record 14 of Set 14 | hobyo
# Processing Record 15 of Set 14 | koumac
# Processing Record 16 of Set 14 | rupert
# Processing Record 17 of Set 14 | pasaco
# Processing Record 18 of Set 14 | hong gai
# Processing Record 19 of Set 14 | otane
# Processing Record 20 of Set 14 | arruda dos vinhos
# Processing Record 21 of Set 14 | namibe
# Processing Record 22 of Set 14 | minturno
# Processing Record 23 of Set 14 | sorong
# Processing Record 24 of Set 14 | carutapera
# Processing Record 25 of Set 14 | lijesnica
# Processing Record 26 of Set 14 | pringsewu
# Processing Record 27 of Set 14 | suoyarvi
# Processing Record 28 of Set 14 | college
# Processing Record 29 of Set 14 | bretten
# Processing Record 30 of Set 14 | zyryanovsk
# Processing Record 31 of Set 14 | voyvozh
# Processing Record 32 of Set 14 | fort nelson
# Processing Record 33 of Set 14 | larreynaga
# Processing Record 34 of Set 14 | wakkanai
# Processing Record 35 of Set 14 | gulmarg
# Processing Record 36 of Set 14 | lorengau
# Processing Record 37 of Set 14 | florence
# Processing Record 38 of Set 14 | dali
# Processing Record 39 of Set 14 | isla vista
# Processing Record 40 of Set 14 | vytegra
# Processing Record 41 of Set 14 | abu samrah
# Processing Record 42 of Set 14 | bosaso
# Processing Record 43 of Set 14 | zhitikara
# City not found. Skipping...
# Processing Record 44 of Set 14 | jizan
# Processing Record 45 of Set 14 | sinnamary
# Processing Record 46 of Set 14 | lubao
# Processing Record 47 of Set 14 | gayeri
# Processing Record 48 of Set 14 | hofn
# Processing Record 49 of Set 14 | reshetylivka
# Processing Record 50 of Set 14 | camana
# Processing Record 1 of Set 15 | edremit
# Processing Record 2 of Set 15 | nkhotakota
# Processing Record 3 of Set 15 | marzuq
# Processing Record 4 of Set 15 | the valley
# Processing Record 5 of Set 15 | whittlesea
# Processing Record 6 of Set 15 | methoni
# Processing Record 7 of Set 15 | phonhong
# Processing Record 8 of Set 15 | carballo
# Processing Record 9 of Set 15 | barroquinha
# Processing Record 10 of Set 15 | tautira
# Processing Record 11 of Set 15 | thinadhoo
# Processing Record 12 of Set 15 | kang
# Processing Record 13 of Set 15 | srandakan
# Processing Record 14 of Set 15 | tacuarembo
# Processing Record 15 of Set 15 | faya
# Processing Record 16 of Set 15 | sibiti
# Processing Record 17 of Set 15 | isparta
# Processing Record 18 of Set 15 | thomaston
# Processing Record 19 of Set 15 | arona
# Processing Record 20 of Set 15 | fenoarivo
# Processing Record 21 of Set 15 | kieta
# Processing Record 22 of Set 15 | ankpa
# Processing Record 23 of Set 15 | kiama
# Processing Record 24 of Set 15 | mocambique
# City not found. Skipping...
# Processing Record 25 of Set 15 | yunjinghong
# City not found. Skipping...
# Processing Record 26 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 27 of Set 15 | shache
# Processing Record 28 of Set 15 | shahrud
# Processing Record 29 of Set 15 | hede
# Processing Record 30 of Set 15 | byron bay
# Processing Record 31 of Set 15 | preston
# Processing Record 32 of Set 15 | westport
# Processing Record 33 of Set 15 | zabol
# Processing Record 34 of Set 15 | durban
# Processing Record 35 of Set 15 | mbala
# Processing Record 36 of Set 15 | dalbandin
# Processing Record 37 of Set 15 | kodinsk
# Processing Record 38 of Set 15 | ankazoabo
# Processing Record 39 of Set 15 | holme
# Processing Record 40 of Set 15 | coos bay
# Processing Record 41 of Set 15 | kingori
# Processing Record 42 of Set 15 | khargapur
# Processing Record 43 of Set 15 | visnes
# Processing Record 44 of Set 15 | paracuru
# Processing Record 45 of Set 15 | fuerte olimpo
# Processing Record 46 of Set 15 | kununurra
# Processing Record 47 of Set 15 | pangnirtung
# Processing Record 48 of Set 15 | quibdo
# Processing Record 49 of Set 15 | nayoro
# Processing Record 50 of Set 15 | cleethorpes
# Processing Record 1 of Set 16 | tongliao
# Processing Record 2 of Set 16 | viedma
# Processing Record 3 of Set 16 | erenhot
# Processing Record 4 of Set 16 | cavalcante
# Processing Record 5 of Set 16 | zhanaozen
# Processing Record 6 of Set 16 | cranbrook
# Processing Record 7 of Set 16 | syracuse
# Processing Record 8 of Set 16 | birao
# Processing Record 9 of Set 16 | kuusamo
# Processing Record 10 of Set 16 | newtownards
# Processing Record 11 of Set 16 | pochutla
# Processing Record 12 of Set 16 | labuhan
# Processing Record 13 of Set 16 | vangazi
# Processing Record 14 of Set 16 | menemen
# Processing Record 15 of Set 16 | nurota
# Processing Record 16 of Set 16 | san buenaventura
# Processing Record 17 of Set 16 | novyye burasy
# Processing Record 18 of Set 16 | chitral
# Processing Record 19 of Set 16 | kasempa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
pd.options.display.float_format = '{:,.2f}'.format
city_data_df.head(10)
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         Mataura -46.19  168.86     57.47        62          26        2.35
# 1  Severo-Kurilsk  50.68  156.12     23.16        68          26       11.92
# 2       Bathsheba  13.22  -59.52     79.41        65          75       19.57
# 3        Souillac -20.52   57.52     81.36        89          75       11.50
# 4      Tombouctou  20.00   -3.00     61.83        20          16       11.63
# 5          Faanui -16.48 -151.75     80.76        74         100       14.63
# 6       Hithadhoo  -0.60   73.08     82.22        72          83       11.03
# 7         Ushuaia -54.80  -68.30     38.86        87         100       27.63
# 8        Hermanus -34.42   19.23     65.80        83          58       18.05
# 9          Dikson  73.51   80.55     -4.67        87         100       24.74
#
#   Country Current Description                 Date
# 0      NZ    scattered clouds  2022-02-13 21:38:31
# 1      RU    scattered clouds  2022-02-13 21:38:31
# 2      BB       broken clouds  2022-02-13 21:38:31
# 3      MU       broken clouds  2022-02-13 21:38:32
# 4      ML          few clouds  2022-02-13 21:38:32
# 5      PF          light rain  2022-02-13 21:38:32
# 6      MV       broken clouds  2022-02-13 21:36:06
# 7      AR       moderate rain  2022-02-13 21:38:33
# 8      ZA       broken clouds  2022-02-13 21:38:33
# 9      RU     overcast clouds  2022-02-13 21:30:17

# %%
new_column_order = ["City", "Country", "Lat", "Lng","Max Temp", 
                    "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#              City Country    Lat    Lng  Max Temp  Humidity  Cloudiness  \
# 0         Mataura      NZ -46.19 168.86     57.47        62          26
# 1  Severo-Kurilsk      RU  50.68 156.12     23.16        68          26
# 2       Bathsheba      BB  13.22 -59.52     79.41        65          75
# 3        Souillac      MU -20.52  57.52     81.36        89          75
# 4      Tombouctou      ML  20.00  -3.00     61.83        20          16
#
#    Wind Speed Current Description
# 0        2.35    scattered clouds
# 1       11.92    scattered clouds
# 2       19.57       broken clouds
# 3       11.50       broken clouds
# 4       11.63          few clouds

# %%
output_data_file = "Weather_Database/cities.csv"
city_data_df.to_csv(output_data_file,index_label="City_ID")
